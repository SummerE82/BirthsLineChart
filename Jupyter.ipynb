# %%
import pandas as pd

# %%
dataframe = pd.read_csv('US_births_2000-2014_SSA.csv')

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
print(dataframe.head())
# Out:
#    year  month  date_of_month  day_of_week  births
# 0  2000      1              1            6    9083
# 1  2000      1              2            7    8006
# 2  2000      1              3            1   11363
# 3  2000      1              4            2   13032
# 4  2000      1              5            3   12558

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
dataframe.plot(x='year', y='births', kind="line") 
plt.title("Births by Year") 
plt.xlabel("Year") 
plt.ylabel("Births")
# Out:
# Text(0, 0.5, 'Births')
